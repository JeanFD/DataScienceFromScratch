# %%
from matplotlib import pyplot as plt

# Pag 46
years =[1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

plt.title("PIB Nominal")

plt.ylabel("Bilhões em Dólares")
plt.show()

# %%
# 47
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

plt.bar(range(len(movies)), num_oscars)

plt.title("Meus Filmes Favoritos")

plt.ylabel("N° de Oscars")
plt.xticks(range(len(movies)), movies)

plt.show()

# %%
# 48
from collections import Counter
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

plt.bar([x+5 for x in histogram.keys()],
        histogram.values(),
        10,
        edgecolor=(0, 0, 0))

plt.axis([-5, 105, 0, 5])

plt.xticks([10 * i for i in range(11)])
plt.xlabel("Notas")
plt.ylabel("N° de Alunos")
plt.title("Distribuição das Notas da 1° Avaliacao")
plt.show()

# %%
# 49
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("""N° de vezes em que ouvi alguém dizer "data science" """)

plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 499, 506])
plt.title("Observe Esse Aumento 'Imenso'!")
plt.show()

# %%
# 50
mentions = [500, 505]
years = [2017, 2018]

plt.bar(years, mentions, 0.8)
plt.xticks(years)
plt.ylabel("""N° de vezes em que ouvi alguém dizer "data science" """)

plt.ticklabel_format(useOffset=False)

plt.axis([2016.5, 2018.5, 0, 550])
plt.title("O Aumento Diminuiu Bastante")
plt.show()

# %%
# 50 / 51

variance = [1, 2, 4, 5, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x+y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label='variance')
plt.plot(xs, bias_squared, 'r-', label='bias^2')
plt.plot(xs, total_error, 'b:', label='total error')

plt.legend(loc=9)
plt.xlabel("complexidade do modelo")
plt.xticks([])
plt.title("O Dilema Viés-Variância")
plt.show()

# %%
# 51 / 52

friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                 xy = (friend_count, minute_count),
                 xytext=(5,-5),
                 textcoords='offset points'
                 )

plt.title("Minutos Diários x Número de Amigos")
plt.xlabel("n° de amigos")
plt.ylabel("minutos diários dedicados ao site")

plt.show()

# %%
# 53
test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85,60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Eixos Não Comparáveis")
plt.xlabel("notas 1° teste")
plt.ylabel("notas 2° teste")

plt.show()


test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85,60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Eixos Não Comparáveis")
plt.xlabel("notas 1° teste")
plt.ylabel("notas 2° teste")

plt.axis("equal")

plt.show()
